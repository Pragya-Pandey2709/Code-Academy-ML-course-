# %% [markdown]
# <a href="https://colab.research.google.com/github/Pragya-Pandey2709/Code-Academy-ML-course-/blob/main/AILAB5_BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BFS
# Using a Python dictionary to act as an adjacency list


graph = {
    'A' : ['B','C','D'],
    'B' : ['E','F'],
    'C' : ['G', 'H'],
    'D' : ['I', 'J'],
    'E' : [],
    'F' : [],
    'G' : [],
    'H' : [],
    'I' : [],
    'J' : [],
}
print(graph)
print('\n')

visited = [] # List to keep track of visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node):
    visited.append(node)
    queue.append(node)    
    print("Sequence generated by Breadth First Algorithm is = \n")  
    
    while queue:
        s = queue.pop(0) 
        print (s, end = " ") 

        for neighbour in graph[s]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)
    
      
             
 # Driver Code
bfs(visited, graph, 'A')
# Out:
# {'A': ['B', 'C', 'D'], 'B': ['E', 'F'], 'C': ['G', 'H'], 'D': ['I', 'J'], 'E': [], 'F': [], 'G': [], 'H': [], 'I': [], 'J': []}
#
#
# Sequence generated by Breadth First Algorithm is =
#
# A B C D E F G H I J
